# %% [markdown]
# <a href="https://colab.research.google.com/github/denverkim/Data-Analysis/blob/main/butler_%EC%98%88%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#    판다스로  파일열기

import pandas as pd

df = pd.read_excel('/content/butler.xlsx')
df
# Out:
#    DrivingAssignment  MilesTraveled  NumberOfDeliveries  TravelTime
# 0                  1            100                   4         9.3
# 1                  2             50                   3         4.8
# 2                  3            100                   4         8.9
# 3                  4            100                   2         6.5
# 4                  5             50                   2         4.2
# 5                  6             80                   2         6.2
# 6                  7             75                   3         7.4
# 7                  8             65                   4         6.0
# 8                  9             90                   3         7.6
# 9                 10             90                   2         6.1

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'DrivingAssignment'}>,
#         <Axes: title={'center': 'MilesTraveled'}>],
#        [<Axes: title={'center': 'NumberOfDeliveries'}>,
#         <Axes: title={'center': 'TravelTime'}>]], dtype=object)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
# x and y split
y = df.TravelTime
x= df.drop('TravelTime',axis=1)
x
# Out:
#    DrivingAssignment  MilesTraveled  NumberOfDeliveries
# 0                  1            100                   4
# 1                  2             50                   3
# 2                  3            100                   4
# 3                  4            100                   2
# 4                  5             50                   2
# 5                  6             80                   2
# 6                  7             75                   3
# 7                  8             65                   4
# 8                  9             90                   3
# 9                 10             90                   2

# %%
df.describe()
# Out:
#        DrivingAssignment  MilesTraveled  NumberOfDeliveries  TravelTime
# count           10.00000        10.0000           10.000000   10.000000
# mean             5.50000        80.0000            2.900000    6.700000
# std              3.02765        19.5789            0.875595    1.629588
# min              1.00000        50.0000            2.000000    4.200000
# 25%              3.25000        67.5000            2.000000    6.025000
# 50%              5.50000        85.0000            3.000000    6.350000
# 75%              7.75000        97.5000            3.750000    7.550000
# max             10.00000       100.0000            4.000000    9.300000

# %%
# tain and test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)
# Out:
# 2    8.9
# 8    7.6
# Name: TravelTime, dtype: float64

# %%
# 회귀분석
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# 평가
lr.score(x_test,y_test)
# Out:
# 0.8189046974880898

# %%
# 교차검증
from sklearn.model_selection import cross_val_score
cross_val_score(lr,x,y,cv=5)
# Out:
# array([ 0.96339355,  0.37906592,  0.76429605, -1.23253506,  0.80015113])

# %%
lr.predict(x_train.iloc[:2])
# Out:
# array([4.08013622, 6.28726705])
