# %% [markdown]
# <a href="https://colab.research.google.com/github/denverkim/Data-Analysis/blob/main/cravens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#    판다스로  파일열기

import pandas as pd

df = pd.read_excel('/content/cravens.xlsx')
df
# Out:
#       Sales    Time    Poten   AdvExp  Share  Change  Accounts   Work  Rating
# 0   3669.88   43.10  74065.1   4582.9   2.51    0.34     74.86  15.05     4.9
# 1   3473.95  108.13  58117.3   5539.8   5.51    0.15    107.32  19.97     5.1
# 2   2295.10   13.82  21118.5   2950.4  10.91   -0.72     96.75  17.34     2.9
# 3   4675.56  186.18  68521.3   2243.1   8.27    0.17    195.12  13.40     3.4
# 4   6125.96  161.79  57805.1   7747.1   9.15    0.50    180.44  17.64     4.6
# 5   2134.94    8.94  37806.9    402.4   5.51    0.15    104.88  16.22     4.5
# 6   5031.66  365.04  50935.3   3140.6   8.54    0.55    256.10  18.80     4.6
# 7   3367.45  220.32  35602.1   2086.2   7.07   -0.49    126.83  19.86     2.3
# 8   6519.45  127.64  46176.8   8846.2  12.54    1.24    203.25  17.42     4.9
# 9   4876.37  105.69  42053.2   5673.1   8.85    0.31    119.51  21.41     2.8
# 10  2468.27   57.72  36829.7   2761.8   5.38    0.37    116.26  16.32     3.1
# ...

# %% [markdown]
# # 사전분석

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Sales'}>,
#         <Axes: title={'center': 'Time'}>,
#         <Axes: title={'center': 'Poten'}>],
#        [<Axes: title={'center': 'AdvExp'}>,
#         <Axes: title={'center': 'Share'}>,
#         <Axes: title={'center': 'Change'}>],
#        [<Axes: title={'center': 'Accounts'}>,
#         <Axes: title={'center': 'Work'}>,
#         <Axes: title={'center': 'Rating'}>]], dtype=object)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#              Sales        Time        Poten        AdvExp      Share  \
# count    25.000000   25.000000     25.00000     25.000000  25.000000
# mean   3374.567600   87.638000  38858.05200   4357.388000   7.564800
# std    1313.068114   86.798348  15714.53848   2689.096982   2.459788
# min    1578.000000    8.130000  20416.90000    402.400000   2.510000
# 25%    2408.110000   13.820000  23990.80000   2243.100000   5.510000
# 50%    3264.200000   57.720000  36272.00000   3571.500000   7.370000
# 75%    4167.440000  127.640000  50935.30000   5673.100000   8.850000
# max    6519.450000  365.040000  74065.10000  10694.200000  12.880000
#
#           Change    Accounts      Work     Rating
# count  25.000000   25.000000  25.00000  25.000000
# mean    0.095600  122.699200  18.06080   3.744000
# std     0.621048   45.578019   3.67007   0.959201
# min    -1.630000   74.860000   7.81000   1.600000
# 25%    -0.100000   88.620000  16.00000   3.100000
# ...

# %%
# x and y split
y = df.Sales
x= df.drop('Sales',axis=1)

# %%
# tain and test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# 상관관계 분석
import seaborn as sns

sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
# 회귀분석
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# 평가
lr.score(x_test,y_test)
# Out:
# -0.5419817076379339

# %%
# 교차검증
from sklearn.model_selection import cross_val_score
cross_val_score(lr,x,y,cv=5)
# Out:
# array([ 0.7790839 ,  0.80100274,  0.77795042, -3.30130631,  0.71888587])

# %%
lr.predict(x_train.iloc[:2])
# Out:
# array([1596.08284075, 2862.06666729])
