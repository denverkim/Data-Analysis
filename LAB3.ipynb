# %% [markdown]
# <a href="https://colab.research.google.com/github/denverkim/Data-Analysis/blob/main/LAB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#판다스로  파일열기
import pandas as pd

telco = pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn.csv')
telco.head()
telco.shape
telco.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# 범주형컬럼을 선택해서 라벨인코딩
# 라벨 인코딩할 범주형 컬럼 지정
label_cols = telco.select_dtypes(include=['object']).columns.tolist()

# label_cols = ["gender", "Partner", "Dependents", "PhoneService", "OnlineSecurity","InternetService"]

# LabelEncoder 객체 생성
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# 각 컬럼에 대해 라벨 인코딩 적용
for col in label_cols:
    telco[col] = le.fit_transform(telco[col])

print(telco[label_cols].head())



le = LabelEncoder()
# Out:
#    customerID  MultipleLines  OnlineBackup  DeviceProtection  TechSupport  \
# 0        5375              1             2                 0            0
# 1        3962              0             0                 2            0
# 2        2564              0             2                 0            0
# 3        5535              1             0                 2            2
# 4        6511              0             0                 0            0
#
#    StreamingTV  StreamingMovies  Contract  PaperlessBilling  PaymentMethod  \
# 0            0                0         0                 1              2
# 1            0                0         1                 0              3
# 2            0                0         0                 1              3
# 3            0                0         1                 0              0
# 4            0                0         0                 1              2
#
#    TotalCharges  Churn
# 0          2505      0
# ...

# %%
telco.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0        5375       0              0        1           0       1
# 1        3962       1              0        0           0      34
# 2        2564       1              0        0           0       2
# 3        5535       1              0        0           0      45
# 4        6511       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
# x and y split
x = telco.drop(['Churn', 'customerID'], axis=1)
y = telco['Churn']
x
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
# train and tests split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
# 의사결정모델
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=0)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)
